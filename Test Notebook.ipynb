# %% [markdown]
# # The purpose of this notebook is to test out different data sets in order to decide which suits best to work on

# %% [markdown]
# ### Problem statement
#
# For this project you must create a data set by `simulating a real-world phenomenon of
# your choosing.` You may pick any phenomenon you wish – you might pick one that is
# of interest to you in your personal or professional life. Then, rather than collect data
# related to the phenomenon, you should `model and synthesise such data using Python.`
# We suggest you use the numpy.random package for this purpose.
#     Specifically, in this project you should:
#
# * Choose a real-world phenomenon that can be measured and for which you could collect at least one-hundred data points across at least four different variables.
# * Investigate the types of variables involved, their likely distributions, and their relationships with each other.
# * Synthesise/simulate a data set as closely matching their properties as possible.
# * Detail your research and implement the simulation in a Jupyter notebook – the data set itself can simply be displayed in an output cell within the notebook.
#
#
# Note that `this project is about simulation` – you must synthesise a data set. Some
# students may already have some real-world data sets in their own files. It is okay to
# base your synthesised data set on these should you wish (please reference it if you do),
# but the main task in this project is to create a synthesised data set. The next section
# gives an example project idea
#
# -------------------

# %% [markdown]
# # Ideas for project
#
# Corona virus
# * galway specefic
# * compare with national / international.
# * simulate exponential growth if no lockdown?

# %% [markdown]
# # Corona Virus

# %%
import pandas as pd

# %%
data = pd.read_csv("https://opendata-geohive.hub.arcgis.com/datasets/d9be85b30d7748b5b7c09450b8aede63_0.csv?outSR=%7B%22latestWkid%22%3A3857%2C%22wkid%22%3A102100%7D") 
data
# Out:
#       OBJECTID  ORIGID CountyName  PopulationCensus16               TimeStamp  \
# 0            1       1     Carlow               56932  2020/02/27 00:00:00+00
# 1            2       2      Cavan               76176  2020/02/27 00:00:00+00
# 2            3       3      Clare              118817  2020/02/27 00:00:00+00
# 3            4       4       Cork              542868  2020/02/27 00:00:00+00
# 4            5       5    Donegal              159192  2020/02/27 00:00:00+00
# ...        ...     ...        ...                 ...                     ...
# 7457      7458      22  Tipperary              159553  2020/12/11 00:00:00+00
# 7458      7459      23  Waterford              116176  2020/12/11 00:00:00+00
# 7459      7460      24  Westmeath               88770  2020/12/11 00:00:00+00
# 7460      7461      25    Wexford              149722  2020/12/11 00:00:00+00
# 7461      7462      26    Wicklow              142425  2020/12/11 00:00:00+00
#
#       IGEasting  IGNorthing      Lat    Long  \
# 0        278661      163444  52.7168 -6.8367
# 1        246380      304501  53.9878 -7.2937
# 2        133493      182732  52.8917 -8.9889
# 3        156242       77860  51.9517 -8.6372
# 4        202615      405691  54.8989 -7.9600
# ...         ...         ...      ...     ...
# 7457     205427      154345  52.6407 -7.9206
# 7458     234676      105809  52.2035 -7.4935
# 7459     238362      255966  53.5524 -7.4219
# 7460     301627      141559  52.5164 -6.5037
# 7461     311162      197894  53.0205 -6.3442
#
#                                                     UGI  ConfirmedCovidCases  \
# 0     http://data.geohive.ie/resource/county/2ae1962...                    0
# 1     http://data.geohive.ie/resource/county/2ae1962...                    0
# 2     http://data.geohive.ie/resource/county/2ae1962...                    0
# 3     http://data.geohive.ie/resource/county/2ae1962...                    0
# 4     http://data.geohive.ie/resource/county/2ae1962...                    0
# ...                                                 ...                  ...
# 7457  http://data.geohive.ie/resource/county/2ae1962...                 1620
# 7458  http://data.geohive.ie/resource/county/2ae1962...                 1117
# 7459  http://data.geohive.ie/resource/county/2ae1962...                 1561
# 7460  http://data.geohive.ie/resource/county/2ae1962...                 1242
# 7461  http://data.geohive.ie/resource/county/2ae1962...                 1674
#
#       PopulationProportionCovidCases  ConfirmedCovidDeaths  \
# 0                                NaN                   NaN
# 1                                NaN                   NaN
# 2                                NaN                   NaN
# 3                                NaN                   NaN
# 4                                NaN                   NaN
# ...                              ...                   ...
# 7457                     1015.336597                   NaN
# 7458                      961.472249                   NaN
# 7459                     1758.476963                   NaN
# 7460                      829.537409                   NaN
# 7461                     1175.355450                   NaN
#
#       ConfirmedCovidRecovered   Shape__Area  Shape__Length
# 0                         NaN  2.432352e+09   3.193486e+05
# 1                         NaN  5.575010e+09   5.159545e+05
# 2                         NaN  8.722542e+09   1.013949e+06
# 3                         NaN  1.952949e+10   2.129949e+06
# 4                         NaN  1.462404e+10   2.145086e+06
# ...                       ...           ...            ...
# 7457                      NaN  1.155120e+10   7.812766e+05
# 7458                      NaN  4.848380e+09   6.431849e+05
# 7459                      NaN  5.208706e+09   4.226693e+05
# 7460                      NaN  6.332221e+09   5.893245e+05
# 7461                      NaN  5.580729e+09   4.275392e+05
#
# [7462 rows x 16 columns]

# %%
data.head()
# Out:
#    OBJECTID  ORIGID CountyName  PopulationCensus16               TimeStamp  \
# 0         1       1     Carlow               56932  2020/02/27 00:00:00+00
# 1         2       2      Cavan               76176  2020/02/27 00:00:00+00
# 2         3       3      Clare              118817  2020/02/27 00:00:00+00
# 3         4       4       Cork              542868  2020/02/27 00:00:00+00
# 4         5       5    Donegal              159192  2020/02/27 00:00:00+00
#
#    IGEasting  IGNorthing      Lat    Long  \
# 0     278661      163444  52.7168 -6.8367
# 1     246380      304501  53.9878 -7.2937
# 2     133493      182732  52.8917 -8.9889
# 3     156242       77860  51.9517 -8.6372
# 4     202615      405691  54.8989 -7.9600
#
#                                                  UGI  ConfirmedCovidCases  \
# 0  http://data.geohive.ie/resource/county/2ae1962...                    0
# 1  http://data.geohive.ie/resource/county/2ae1962...                    0
# 2  http://data.geohive.ie/resource/county/2ae1962...                    0
# 3  http://data.geohive.ie/resource/county/2ae1962...                    0
# 4  http://data.geohive.ie/resource/county/2ae1962...                    0
#
#    PopulationProportionCovidCases  ConfirmedCovidDeaths  \
# 0                             NaN                   NaN
# 1                             NaN                   NaN
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
#
#    ConfirmedCovidRecovered   Shape__Area  Shape__Length
# 0                      NaN  2.432352e+09   3.193486e+05
# 1                      NaN  5.575010e+09   5.159545e+05
# 2                      NaN  8.722542e+09   1.013949e+06
# 3                      NaN  1.952949e+10   2.129949e+06
# 4                      NaN  1.462404e+10   2.145086e+06

# %%
data["CountyName"].value_counts()
# Out:
# Carlow       287
# Meath        287
# Limerick     287
# Monaghan     287
# Laois        287
# Louth        287
# Leitrim      287
# Tipperary    287
# Sligo        287
# Kerry        287
# Longford     287
# Wexford      287
# Clare        287
# Mayo         287
# Roscommon    287
# Donegal      287
# Galway       287
# Cavan        287
# Offaly       287
# Westmeath    287
# Waterford    287
# Dublin       287
# Kildare      287
# Wicklow      287
# Kilkenny     287
# Cork         287
# Name: CountyName, dtype: int64

# %%
galData = data.loc[data["CountyName"] == "Galway"]
galData
# Out:
#       OBJECTID  ORIGID CountyName  PopulationCensus16               TimeStamp  \
# 6            7       7     Galway              258058  2020/02/27 00:00:00+00
# 32          33       7     Galway              258058  2020/03/01 00:00:00+00
# 58          59       7     Galway              258058  2020/03/02 00:00:00+00
# 84          85       7     Galway              258058  2020/03/03 00:00:00+00
# 110        111       7     Galway              258058  2020/03/04 00:00:00+00
# ...        ...     ...        ...                 ...                     ...
# 7338      7339       7     Galway              258058  2020/12/07 00:00:00+00
# 7364      7365       7     Galway              258058  2020/12/08 00:00:00+00
# 7390      7391       7     Galway              258058  2020/12/09 00:00:00+00
# 7416      7417       7     Galway              258058  2020/12/10 00:00:00+00
# 7442      7443       7     Galway              258058  2020/12/11 00:00:00+00
#
#       IGEasting  IGNorthing      Lat    Long  \
# 6        151045      235818  53.3705 -8.7362
# 32       151045      235818  53.3705 -8.7362
# 58       151045      235818  53.3705 -8.7362
# 84       151045      235818  53.3705 -8.7362
# 110      151045      235818  53.3705 -8.7362
# ...         ...         ...      ...     ...
# 7338     151045      235818  53.3705 -8.7362
# 7364     151045      235818  53.3705 -8.7362
# 7390     151045      235818  53.3705 -8.7362
# 7416     151045      235818  53.3705 -8.7362
# 7442     151045      235818  53.3705 -8.7362
#
#                                                     UGI  ConfirmedCovidCases  \
# 6     http://data.geohive.ie/resource/county/2ae1962...                    0
# 32    http://data.geohive.ie/resource/county/2ae1962...                    0
# 58    http://data.geohive.ie/resource/county/2ae1962...                    0
# 84    http://data.geohive.ie/resource/county/2ae1962...                    0
# 110   http://data.geohive.ie/resource/county/2ae1962...                    0
# ...                                                 ...                  ...
# 7338  http://data.geohive.ie/resource/county/2ae1962...                 2745
# 7364  http://data.geohive.ie/resource/county/2ae1962...                 2755
# 7390  http://data.geohive.ie/resource/county/2ae1962...                 2768
# 7416  http://data.geohive.ie/resource/county/2ae1962...                 2785
# 7442  http://data.geohive.ie/resource/county/2ae1962...                 2789
#
#       PopulationProportionCovidCases  ConfirmedCovidDeaths  \
# 6                                NaN                   NaN
# 32                               NaN                   NaN
# 58                               NaN                   NaN
# 84                               NaN                   NaN
# 110                              NaN                   NaN
# ...                              ...                   ...
# 7338                     1063.714359                   NaN
# 7364                     1067.589457                   NaN
# 7390                     1072.627084                   NaN
# 7416                     1079.214750                   NaN
# 7442                     1080.764789                   NaN
#
#       ConfirmedCovidRecovered   Shape__Area  Shape__Length
# 6                         NaN  1.707916e+10   1.972288e+06
# 32                        NaN  1.707916e+10   1.972288e+06
# 58                        NaN  1.707916e+10   1.972288e+06
# 84                        NaN  1.707916e+10   1.972288e+06
# 110                       NaN  1.707916e+10   1.972288e+06
# ...                       ...           ...            ...
# 7338                      NaN  1.707916e+10   1.972288e+06
# 7364                      NaN  1.707916e+10   1.972288e+06
# 7390                      NaN  1.707916e+10   1.972288e+06
# 7416                      NaN  1.707916e+10   1.972288e+06
# 7442                      NaN  1.707916e+10   1.972288e+06
#
# [287 rows x 16 columns]

# %%
df = galData[["TimeStamp", "CountyName", "ConfirmedCovidCases",  "ConfirmedCovidDeaths" ]]
df
# Out:
#                    TimeStamp CountyName  ConfirmedCovidCases  \
# 6     2020/02/27 00:00:00+00     Galway                    0
# 32    2020/03/01 00:00:00+00     Galway                    0
# 58    2020/03/02 00:00:00+00     Galway                    0
# 84    2020/03/03 00:00:00+00     Galway                    0
# 110   2020/03/04 00:00:00+00     Galway                    0
# ...                      ...        ...                  ...
# 7338  2020/12/07 00:00:00+00     Galway                 2745
# 7364  2020/12/08 00:00:00+00     Galway                 2755
# 7390  2020/12/09 00:00:00+00     Galway                 2768
# 7416  2020/12/10 00:00:00+00     Galway                 2785
# 7442  2020/12/11 00:00:00+00     Galway                 2789
#
#       ConfirmedCovidDeaths
# 6                      NaN
# 32                     NaN
# 58                     NaN
# 84                     NaN
# 110                    NaN
# ...                    ...
# 7338                   NaN
# 7364                   NaN
# 7390                   NaN
# 7416                   NaN
# 7442                   NaN
#
# [287 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# %%
df.plot(x="TimeStamp", y="ConfirmedCovidCases")

# %% [markdown]
# # Marathon Results

# %% [markdown]
# Marathon results
#
# https://www.kaggle.com/rojour/boston-results
#
# https://towardsdatascience.com/half-marathon-finish-time-prediction-part-1-5807760033eb
#
# https://www.kaggle.com/daniboy370/boston-marathon-2019
#
#
# https://raw.githubusercontent.com/adrian3/Boston-Marathon-Data-Project/master/results2019.csv
# https://github.com/adrian3/Boston-Marathon-Data-Project

# %%
marathonData = pd.read_csv("./results2019.csv") 
marathonData
# Out:
# C:\Users\leese\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0,20,22,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       place_overall    bib               name age gender          city state  \
# 0                 1      2  Cherono, Lawrence  30      M       Eldoret   NaN
# 1                 2      6     Desisa, Lelisa  29      M          Ambo   NaN
# 2                 3      7  Kipkemoi, Kenneth  34      M       Eldoret   NaN
# 3                 4      8      Kandie, Felix  32      M          Iten   NaN
# 4                 5     11    Kirui, Geoffrey  26      M      Keringet   NaN
# ...             ...    ...                ...  ..    ...           ...   ...
# 26641         26653  23909     Mcninch, Brett  42      M   New Lebanon   OH
# 26642         26654  23949    Oconell, Justin  28      M      Franklin   MA
# 26643         26655  15946        Young, John  53      M         Salem   MA
# 26644         26656  23937      Smith, Denise  51      F  Fort Collins   CO
# 26645         26657  23958       Reilly, Bill  66      M   Kew Gardens   NY
#
#       country_residence contry_citizenship  name_suffix  ...  Unnamed: 40  \
# 0                 Kenya              Kenya          NaN  ...          NaN
# 1               Ethiopi            Ethiopi          NaN  ...          NaN
# 2                 Kenya              Kenya          NaN  ...          NaN
# 3                 Kenya              Kenya          NaN  ...          NaN
# 4                 Kenya              Kenya          NaN  ...          NaN
# ...                 ...                ...          ...  ...          ...
# 26641           United             United           NaN  ...          NaN
# 26642           United             United           NaN  ...          NaN
# 26643           United             United           NaN  ...          NaN
# 26644           United             United           NaN  ...          NaN
# 26645           United             United           NaN  ...          NaN
#
#        Unnamed: 41  Unnamed: 42  Unnamed: 43  Unnamed: 44  Unnamed: 45  \
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 26641          NaN          NaN          NaN          NaN          NaN
# 26642          NaN          NaN          NaN          NaN          NaN
# 26643          NaN          NaN          NaN          NaN          NaN
# 26644          NaN          NaN          NaN          NaN          NaN
# 26645          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 46  Unnamed: 47  Unnamed: 48  Unnamed: 49
# 0              NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...
# 26641          NaN          NaN          NaN          NaN
# 26642          NaN          NaN          NaN          NaN
# 26643          NaN          NaN          NaN          NaN
# 26644          NaN          NaN          NaN          NaN
# 26645          NaN          NaN          NaN          NaN
#
# [26646 rows x 50 columns]

# %%
marathonData.head()
# Out:
#   place_overall bib               name age gender      city state  \
# 0             1   2  Cherono, Lawrence  30      M   Eldoret   NaN
# 1             2   6     Desisa, Lelisa  29      M      Ambo   NaN
# 2             3   7  Kipkemoi, Kenneth  34      M   Eldoret   NaN
# 3             4   8      Kandie, Felix  32      M      Iten   NaN
# 4             5  11    Kirui, Geoffrey  26      M  Keringet   NaN
#
#   country_residence contry_citizenship  name_suffix  ...  Unnamed: 40  \
# 0             Kenya              Kenya          NaN  ...          NaN
# 1           Ethiopi            Ethiopi          NaN  ...          NaN
# 2             Kenya              Kenya          NaN  ...          NaN
# 3             Kenya              Kenya          NaN  ...          NaN
# 4             Kenya              Kenya          NaN  ...          NaN
#
#    Unnamed: 41  Unnamed: 42  Unnamed: 43  Unnamed: 44  Unnamed: 45  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 46  Unnamed: 47  Unnamed: 48  Unnamed: 49
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 50 columns]

# %%
mdf = marathonData[["gender", "age", "official_time",  "place_overall" ]]
mdf
# Out:
#       gender age official_time place_overall
# 0          M  30      02:07:57             1
# 1          M  29      02:07:59             2
# 2          M  34      02:08:07             3
# 3          M  32      02:08:54             4
# 4          M  26      02:08:55             5
# ...      ...  ..           ...           ...
# 26641      M  42      07:14:12         26653
# 26642      M  28      07:16:19         26654
# 26643      M  53      07:17:35         26655
# 26644      F  51      07:25:39         26656
# 26645      M  66      07:43:48         26657
#
# [26646 rows x 4 columns]

# %% [markdown]
# # Strava Data

# %%
strava = pd.read_csv("./Strava/activities.csv") 
strava
# Out:
#      Activity ID              Activity Date        Activity Name  \
# 0      282668945   Apr 10, 2015, 2:02:56 PM  A bit of a hill Run
# 1      285418571   Apr 14, 2015, 6:20:17 PM          Evening Run
# 2      285467444   Apr 14, 2015, 7:55:17 PM          Evening Run
# 3      665542455    Aug 5, 2016, 4:19:40 PM        Afternoon Run
# 4      672275108  Aug 11, 2016, 12:58:38 PM    30 on/off sprints
# ..           ...                        ...                  ...
# 285   4431259818    Dec 5, 2020, 8:18:46 AM         Morning Swim
# 286   4436960391   Dec 6, 2020, 11:23:34 AM            Lunch Run
# 287   4441748258   Dec 7, 2020, 12:46:19 PM           Lunch Swim
# 288   4445562624   Dec 8, 2020, 11:58:31 AM            Lunch Run
# 289   4454058715  Dec 10, 2020, 12:31:40 PM            Lunch Run
#
#     Activity Type Activity Description  Elapsed Time Distance  \
# 0             Run                  NaN          1963     5.70
# 1             Run                  NaN          2910     7.52
# 2             Run                  NaN           783     2.29
# 3             Run                  NaN          1866     5.02
# 4             Run                  NaN          1349     3.21
# ..            ...                  ...           ...      ...
# 285          Swim                  NaN          2336    1,225
# 286           Run                  NaN          2253     6.19
# 287          Swim                  NaN          1897    1,000
# 288           Run                  NaN          2394     6.86
# 289           Run                  NaN          1507     4.39
#
#      Relative Effort  Commute Activity Gear  ... Precipitation Probability  \
# 0                NaN    False           NaN  ...                       NaN
# 1                NaN    False           NaN  ...                       NaN
# 2                NaN    False           NaN  ...                       NaN
# 3                NaN    False           NaN  ...                       NaN
# 4                NaN    False           NaN  ...                       NaN
# ..               ...      ...           ...  ...                       ...
# 285              NaN    False           NaN  ...                       NaN
# 286             42.0    False           NaN  ...                       0.0
# 287              NaN    False           NaN  ...                       NaN
# 288             74.0    False           NaN  ...                       0.0
# 289             29.0    False           NaN  ...                       0.0
#
#      Precipitation Type  Cloud Cover  Weather Visibility  UV Index  \
# 0                   NaN          NaN                 NaN       NaN
# 1                   NaN          NaN                 NaN       NaN
# 2                   NaN          NaN                 NaN       NaN
# 3                   NaN          NaN                 NaN       NaN
# 4                   NaN          NaN                 NaN       NaN
# ..                  ...          ...                 ...       ...
# 285                 NaN          NaN                 NaN       NaN
# 286                 NaN         0.87             10484.0       0.0
# 287                 NaN          NaN                 NaN       NaN
# 288                 NaN         0.22             16093.0       0.0
# 289                 NaN         0.99              9281.0       0.0
#
#      Weather Ozone  \
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 285            NaN
# 286     256.500000
# 287            NaN
# 288     297.899994
# 289     262.100006
#
#      translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
#
#      translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
#
#      translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
#
#      translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
#
# [290 rows x 78 columns]

# %%
dfStrava = strava[["Activity Date", "Activity Type", "Elapsed Time",  "Distance", "Moving Time", "Max Speed","Average Speed","Calories"  ]]
dfStrava
# Out:
#                  Activity Date Activity Type  Elapsed Time Distance  \
# 0     Apr 10, 2015, 2:02:56 PM           Run          1963     5.70
# 1     Apr 14, 2015, 6:20:17 PM           Run          2910     7.52
# 2     Apr 14, 2015, 7:55:17 PM           Run           783     2.29
# 3      Aug 5, 2016, 4:19:40 PM           Run          1866     5.02
# 4    Aug 11, 2016, 12:58:38 PM           Run          1349     3.21
# ..                         ...           ...           ...      ...
# 285    Dec 5, 2020, 8:18:46 AM          Swim          2336    1,225
# 286   Dec 6, 2020, 11:23:34 AM           Run          2253     6.19
# 287   Dec 7, 2020, 12:46:19 PM          Swim          1897    1,000
# 288   Dec 8, 2020, 11:58:31 AM           Run          2394     6.86
# 289  Dec 10, 2020, 12:31:40 PM           Run          1507     4.39
#
#      Moving Time  Max Speed  Average Speed    Calories
# 0         1858.0        7.8            NaN  515.881958
# 1         2662.0        6.3            NaN  669.876953
# 2          665.0        6.2            NaN  213.282501
# 3         1809.0        5.0            NaN  454.047150
# 4          973.0        9.1            NaN  290.768829
# ..           ...        ...            ...         ...
# 285       1549.0        1.1       0.790833  253.000000
# 286       2186.0        4.3       2.834721  514.000000
# 287       1225.0        0.9       0.816327  206.000000
# 288       2347.0        4.4       2.925522  624.000000
# 289       1375.0        4.2       3.196655  341.000000
#
# [290 rows x 8 columns]

# %%
StravaData = dfStrava.loc[dfStrava["Activity Type"] == "Run"]
StravaData
# Out:
#                  Activity Date Activity Type  Elapsed Time Distance  \
# 0     Apr 10, 2015, 2:02:56 PM           Run          1963     5.70
# 1     Apr 14, 2015, 6:20:17 PM           Run          2910     7.52
# 2     Apr 14, 2015, 7:55:17 PM           Run           783     2.29
# 3      Aug 5, 2016, 4:19:40 PM           Run          1866     5.02
# 4    Aug 11, 2016, 12:58:38 PM           Run          1349     3.21
# ..                         ...           ...           ...      ...
# 280   Nov 30, 2020, 2:59:40 PM           Run          2300     5.87
# 283    Dec 2, 2020, 4:00:41 PM           Run          2702     5.07
# 286   Dec 6, 2020, 11:23:34 AM           Run          2253     6.19
# 288   Dec 8, 2020, 11:58:31 AM           Run          2394     6.86
# 289  Dec 10, 2020, 12:31:40 PM           Run          1507     4.39
#
#      Moving Time  Max Speed  Average Speed    Calories
# 0         1858.0        7.8            NaN  515.881958
# 1         2662.0        6.3            NaN  669.876953
# 2          665.0        6.2            NaN  213.282501
# 3         1809.0        5.0            NaN  454.047150
# 4          973.0        9.1            NaN  290.768829
# ..           ...        ...            ...         ...
# 280       2224.0        4.0       2.640018  534.000000
# 283       1846.0        3.9       2.746533  438.000000
# 286       2186.0        4.3       2.834721  514.000000
# 288       2347.0        4.4       2.925522  624.000000
# 289       1375.0        4.2       3.196655  341.000000
#
# [151 rows x 8 columns]

# %%
x = StravaData["Distance"]
y = StravaData["Activity Date"]
plt.hist(x)
# Out:
# (array([19., 17., 17., 13., 22., 15., 12., 12., 12., 12.]),
#  array([  0. ,  11.9,  23.8,  35.7,  47.6,  59.5,  71.4,  83.3,  95.2,
#         107.1, 119. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Research
#
# https://data.gov.ie/blog/coronavirus-covid-19
#
# https://data.gov.ie/
#
# https://covid19ireland-geohive.hub.arcgis.com/pages/helpfaqs

# %% [markdown]
# # References
#
# [[1]](www.address.com)
#
# [1] Title; Website; www.address.com
